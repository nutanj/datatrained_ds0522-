# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r'F:\nutan\capstone project\lit. vs. crimes.xlsx')
df
# Out:
#              STATE/UT    2001    2002    2003    2004    2005    2006    2007  \
# 0      ANDHRA PRADESH  130089  143610  156951  158756  157123  173909  175087
# 1   ARUNACHAL PRADESH    2342    2228    2061    2256    2304    2294    2286
# 2               ASSAM   36877   36346   38195   40675   42006   43673   45282
# 3               BIHAR   88432   94040   92263  108060   97850  100665  109420
# 4        CHHATTISGARH   38460   37950   38449   41927   43633   45177   45845
# 5                 GOA    2341    2440    2244    2127    2119    2204    2479
# 6             GUJARAT  103419  106675  103709  105469  113414  120972  123195
# 7             HARYANA   38759   40152   38612   39096   42664   50509   51597
# 8    HIMACHAL PRADESH   11499   12243   12011   12326   12345   13093   14222
# 9     JAMMU & KASHMIR   19505   19967   21233   21191   20115   20787   21443
# 10          JHARKHAND   25447   31439   32203   31439   35175   36364   38489
# ...

# %%
df.shape
# Out:
# (35, 17)

# %% [markdown]
# this dataset has 35 rows and 17 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   STATE/UT              35 non-null     object
#  1   2001                  35 non-null     int64
#  2   2002                  35 non-null     int64
#  3   2003                  35 non-null     int64
#  4   2004                  35 non-null     int64
#  5   2005                  35 non-null     int64
#  6   2006                  35 non-null     int64
#  7   2007                  35 non-null     int64
#  8   2008                  35 non-null     int64
#  9   2009                  35 non-null     int64
#  10  2010                  35 non-null     int64
#  11  2011                  35 non-null     int64
#  12  2012                  35 non-null     int64
#  13  Total IPC crimes      35 non-null     int64
#  14  literacy rate         35 non-null     float64
# ...

# %% [markdown]
# it has no null values and all the data are in int and float value.

# %%
df.describe()
# Out:
#                 2001           2002           2003           2004  \
# count      35.000000      35.000000      35.000000      35.000000
# mean    52105.485714   52270.485714   50386.400000   53875.228571
# std     61698.141054   61244.726015   58881.965977   62982.007250
# min        36.000000      53.000000      31.000000      70.000000
# 25%      2341.500000    2512.000000    2390.500000    2191.500000
# 50%     25447.000000   28794.000000   28756.000000   25630.000000
# 75%    103633.000000  101237.000000   94940.500000  106357.500000
# max    181741.000000  191799.000000  191078.000000  196867.000000
#
#                 2005           2006           2007           2008  \
# count      35.000000      35.000000      35.000000      35.000000
# mean    53676.200000   52197.542857   58449.657143   61220.828571
# std     62001.356517   62972.108212   66638.929278   69430.671166
# min        42.000000      80.000000      56.000000      95.000000
# ...

# %%
df= df.drop(columns = [2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012], axis=1)
df.head()
# Out:
#             STATE/UT    2001  Total IPC crimes  literacy rate  \
# 0     ANDHRA PRADESH  130089           2018981           67.7
# 1  ARUNACHAL PRADESH    2342             27652           67.0
# 2              ASSAM   36877            597764           73.2
# 3              BIHAR   88432           1346293           63.8
# 4       CHHATTISGARH   38460            561027           71.0
#
#    male literacy rate  female literacy rate
# 0                75.6                  59.7
# 1                73.7                  59.6
# 2                78.8                  67.3
# 3                73.5                  53.3
# 4                81.5                  60.6

# %%
df= df.drop(columns = [2001], axis=1)

# %%
sns.distplot(df['Total IPC crimes'])
# Out:
# <AxesSubplot:xlabel='Total IPC crimes', ylabel='Density'>

# %%
sns.distplot(df['literacy rate'])
# Out:
# <AxesSubplot:xlabel='literacy rate', ylabel='Density'>

# %% [markdown]
# sns.distplot(df['male literacy rate'])

# %% [markdown]
# sns.distplot(df['female literacy rate'])

# %%
df.skew()
# Out:
# Total IPC crimes        0.844068
# literacy rate           0.019361
# male literacy rate     -0.121199
# female literacy rate   -0.019433
# dtype: float64

# %% [markdown]
# the skewness is considerable hence these plots are considered as normal distribution.

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax=sns.boxplot(data=df)
plt.show()

# %% [markdown]
# from this boxplot we can see that there is no outliers.

# %%
sns.relplot(x='Total IPC crimes',y='literacy rate',data=df)
plt.show()

# %%
sns.relplot(x='Total IPC crimes',y='male literacy rate',data=df)
plt.show()

# %%
sns.relplot(x='Total IPC crimes',y='female literacy rate',data=df)
plt.show()

# %%
sns.regplot(x='Total IPC crimes', y='literacy rate', data=df)
# Out:
# <AxesSubplot:xlabel='Total IPC crimes', ylabel='literacy rate'>

# %%
plt.scatter(df['literacy rate'],df['Total IPC crimes'])
plt.show()

# %%
plt.scatter(df['male literacy rate'],df['Total IPC crimes'])
plt.show()

# %%
plt.scatter(df['female literacy rate'],df['Total IPC crimes'])
plt.show()

# %%
df.head()
# Out:
#             STATE/UT  Total IPC crimes  literacy rate  male literacy rate  \
# 0     ANDHRA PRADESH           2018981           67.7                75.6
# 1  ARUNACHAL PRADESH             27652           67.0                73.7
# 2              ASSAM            597764           73.2                78.8
# 3              BIHAR           1346293           63.8                73.5
# 4       CHHATTISGARH            561027           71.0                81.5
#
#    female literacy rate
# 0                  59.7
# 1                  59.6
# 2                  67.3
# 3                  53.3
# 4                  60.6

# %%
df=df.drop(columns=['STATE/UT'])

# %%
df.head(3)
# Out:
#    Total IPC crimes  literacy rate  male literacy rate  female literacy rate
# 0           2018981           67.7                75.6                  59.7
# 1             27652           67.0                73.7                  59.6
# 2            597764           73.2                78.8                  67.3

# %%
df.corr()
# Out:
#                       Total IPC crimes  literacy rate  male literacy rate  \
# Total IPC crimes              1.000000      -0.357375           -0.276093
# literacy rate                -0.357375       1.000000            0.956839
# male literacy rate           -0.276093       0.956839            1.000000
# female literacy rate         -0.381170       0.979898            0.883201
#
#                       female literacy rate
# Total IPC crimes                 -0.381170
# literacy rate                     0.979898
# male literacy rate                0.883201
# female literacy rate              1.000000

# %% [markdown]
# as we see the correlation between Total IPC crimes and literacy rate is -0.35 or the literacy rate(male and female) falls under the range of -0.2 to -0.4 hence, it indicates the strong neagative correltion. that shows when the literacy rate increases the cdimes decreases and the crimes increases as the literacy rate decreases.

# %% [markdown]
# also from the reltional plot we observe that the crimes are more concentrated in the low literacy rate region and more scattered in high literacy rater region. hence we can assume that the states having more literacy rate have less numbers of crimes.
